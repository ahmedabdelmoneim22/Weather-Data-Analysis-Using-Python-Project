# %%
print("Weather Data Analysis Using Python")
# Out:
# Weather Data Analysis Using Python

# %%
print("In this project, we will use:-")
# Out:
# In this project, we will use:-

# %%
print(
"""Functions We Will Use:-
1.nunique() & unique().
2.value_counts().
3.Filtering.
4.groupby().
5.getgroup().
6.isnull()&notnull().
7.rename().
8.mean().
9.std().
10.var().
11.str.contains.
12.And (&) Operator.
13.Or(|) Operator.
14.min () & max().
"""
)
# Out:
# Functions We Will Use:-
# 1.nunique() & unique().
# 2.value_counts().
# 3.Filtering.
# 4.groupby().
# 5.getgroup().
# 6.isnull()&notnull().
# 7.rename().
# 8.mean().
# 9.std().
# 10.var().
# 11.str.contains.
# 12.And (&) Operator.
# 13.Or(|) Operator.
# 14.min () & max().

# %%
import pandas as pd

# %%
print("read Weather Dataset")
# Out:
# read Weather Dataset

# %%
data = pd.read_csv("file.csv")#Read The Weather Dataset.

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
print("How to Analyze DataFrames ?")
# Out:
# How to Analyze DataFrames ?

# %%
print(".head():-it shows the first N rows in the data (N=5).")
data.head(8)
# Out:
# .head():-it shows the first N rows in the data (N=5).
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# ...

# %%
print(".shape:-it shows the Total Num of rows and Num of columns of the Dataframe.")
data.shape
# Out:
# .shape:-it shows the Total Num of rows and Num of columns of the Dataframe.
# (8784, 8)

# %%
print(".index:-This Attribute provides the index of the Dataframe.")
data.index
# Out:
# .index:-This Attribute provides the index of the Dataframe.
# RangeIndex(start=0, stop=8784, step=1)

# %%
print(".columns:-It Shows the name of each column.")
data.columns
# Out:
# .columns:-It Shows the name of each column.
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
print("Name of First Column")
data.columns[0]
# Out:
# Name of First Column
# 'Date/Time'

# %%
print("Names of the Columns of DataFrame")
for column in data.columns:
    print(column)
# Out:
# Names of the Columns of DataFrame
# Date/Time
# Temp_C
# Dew Point Temp_C
# Rel Hum_%
# Wind Speed_km/h
# Visibility_km
# Press_kPa
# Weather

# %%
print(".dtypes:-It shows The Data-Type of each column")
data.dtypes
# Out:
# .dtypes:-It shows The Data-Type of each column
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
print(".unique():-in a column it shows all the unique values.")
print("it can on a single column only,not on the whole dataframe.")
data['Weather'].unique()
# Out:
# .unique():-in a column it shows all the unique values.
# it can on a single column only,not on the whole dataframe.
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
# ...

# %%
print("Weather unique values")
# Out:
# Weather unique values

# %%
print("All Weather unique values")
for uniquevalue in data['Weather'].unique():
    print(uniquevalue)
# Out:
# All Weather unique values
# Fog
# Freezing Drizzle,Fog
# Mostly Cloudy
# Cloudy
# Rain
# Rain Showers
# Mainly Clear
# Snow Showers
# Snow
# Clear
# Freezing Rain,Fog
# Freezing Rain
# Freezing Drizzle
# Rain,Snow
# Moderate Snow
# Freezing Drizzle,Snow
# Freezing Rain,Snow Grains
# Snow,Blowing Snow
# Freezing Fog
# Haze
# Rain,Fog
# Drizzle,Fog
# Drizzle
# Freezing Drizzle,Haze
# Freezing Rain,Haze
# Snow,Haze
# Snow,Fog
# Snow,Ice Pellets
# Rain,Haze
# Thunderstorms,Rain
# Thunderstorms,Rain Showers
# Thunderstorms,Heavy Rain Showers
# Thunderstorms,Rain Showers,Fog
# Thunderstorms
# Thunderstorms,Rain,Fog
# Thunderstorms,Moderate Rain Showers,Fog
# Rain Showers,Fog
# Rain Showers,Snow Showers
# Snow Pellets
# Rain,Snow,Fog
# Moderate Rain,Fog
# Freezing Rain,Ice Pellets,Fog
# Drizzle,Ice Pellets,Fog
# Drizzle,Snow
# Rain,Ice Pellets
# Drizzle,Snow,Fog
# Rain,Snow Grains
# Rain,Snow,Ice Pellets
# Snow Showers,Fog
# Moderate Snow,Blowing Snow

# %%
print(".nunique():-It shows the total Num of unique values in each column of DataFrame.")
data.nunique()
# Out:
# .nunique():-It shows the total Num of unique values in each column of DataFrame.
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
print(".count:-it shows the total no of non-null values in each column of DataFrame.")
print("Number of non-null values")
data.count()#count_of_is_not_null.
# Out:
# .count:-it shows the total no of non-null values in each column of DataFrame.
# Number of non-null values
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
print(".value_counts:-It shows all the unique values with their count in DataFrame.")
print("Count of unique value")
data['Weather'].value_counts()
# Out:
# .value_counts:-It shows all the unique values with their count in DataFrame.
# Count of unique value
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# ...

# %%
print(".info():-Provides Basic infromation about The Dataframe.")
# Out:
# .info():-Provides Basic infromation about The Dataframe.

# %%
print("DataFrame.info:-Print a Summary of a DataFrame.")
data.info()
# Out:
# DataFrame.info:-Print a Summary of a DataFrame.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
print("Q)1.Find all the unique 'Wind Speed' values in the Data.")
data.head(2)
# Out:
# Q)1.Find all the unique 'Wind Speed' values in the Data.
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
print("Number of nunique values:-")
data['Wind Speed_km/h'].nunique()
# Out:
# Number of nunique values:-
# 34

# %%
print("Print unique values and datatype")
data['Wind Speed_km/h'].unique()
# Out:
# Print unique values and datatype
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
print("Q)2.Find the number of times when the Weather is exactly Clear.")
data.head(2)
# Out:
# Q)2.Find the number of times when the Weather is exactly Clear.
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
print("Count>>The Number of Value")
data.Weather.value_counts()
# Out:
# Count>>The Number of Value
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# Filtering.
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
# Filtering.
data.Weather == 'Clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
# Filtering.
print("Select * From data Where Weather == 'Clear';")
data[data.Weather == 'Clear']
# Out:
# Select * From data Where Weather == 'Clear';
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
print("This is Like data[data.Weather == 'Clear']")
data.groupby('Weather').get_group('Clear')
# Out:
# This is Like data[data.Weather == 'Clear']
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
print("Q)3.Find the number of times when the 'Wind Speed was exactly 4 km/h'.")
print("Select * From data Where Wind Speed_km/h = 4")
data[data['Wind Speed_km/h'] == 4]
# Out:
# Q)3.Find the number of times when the 'Wind Speed was exactly 4 km/h'.
# Select * From data Where Wind Speed_km/h = 4
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# ...

# %%
data[data['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
print("Q.4)Find out all The Null Values in the Data.")
print("Print Null Values in the Data.")
data.isnull()
# Out:
# Q.4)Find out all The Null Values in the Data.
# Print Null Values in the Data.
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# ...

# %%
print("Q.4)Find out All the Null Values in the Data.")
data.isnull().sum()#Find Null Values in Columns.
# Out:
# Q.4)Find out All the Null Values in the Data.
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
print("Find All not null Values in Data.")
data.notnull().sum()
# Out:
# Find All not null Values in Data.
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
print("Q.5)Rename the column name 'Weather' of The Dataframe to 'Weather Condition'.")
data.head(2)
# Out:
# Q.5)Rename the column name 'Weather' of The Dataframe to 'Weather Condition'.
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
print(">>Rename to Weather Condition<<")
data.rename(columns = {'Weather':'Weather Condition'},
           inplace = True)
# Out:
# >>Rename to Weather Condition<<

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
print("Q.6)What is the mean 'Visibility'?")
# Out:
# Q.6)What is the mean 'Visibility'?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
print("Calculate Visibility_km")
print("The Maximum Horizontal Distance that the person with normal vision can.")
print("The mean Average of Visibility_km=",data.Visibility_km.mean())
# Out:
# Calculate Visibility_km
# The Maximum Horizontal Distance that the person with normal vision can.
# The mean Average of Visibility_km= 27.664446721311478

# %%
print("Q.7)What is the Standard Deviation of 'Pressure' in this data?")
print("The Standard Deviation of Pressure=",data.Press_kPa.std())
# Out:
# Q.7)What is the Standard Deviation of 'Pressure' in this data?
# The Standard Deviation of Pressure= 0.8440047459486474

# %%
print("Q.8)Whats is the Variance of 'Relative Humidity' in this Data ?")
print("The Variance of 'Relative Humidity'=",data["Rel Hum_%"].var())
# Out:
# Q.8)Whats is the Variance of 'Relative Humidity' in this Data ?
# The Variance of 'Relative Humidity'= 286.2485501984998

# %%
print("Q.9)Find all instances when 'Snow' was recorded.")
data['Weather Condition'].value_counts()
# Out:
# Q.9)Find all instances when 'Snow' was recorded.
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# ...

# %%
#Filtering.
print("Select * From data Where Weather Condition = 'Snow'")
data[data['Weather Condition'] == 'Snow']
# Out:
# Select * From data Where Weather Condition = 'Snow'
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# ...

# %%
# str.contains;
print("Select * From data Where Weather Condition = 'Snow'")
data[data['Weather Condition'].str.contains('Snow')]
# Out:
# Select * From data Where Weather Condition = 'Snow'
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# ...

# %%
# str.contains.
#Select 50rows * From data where Weather Condition = 'Snow';
data[data['Weather Condition'].str.contains('Snow')].head(50)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   1/2/2012 17:00    -2.1              -9.5         57               22
# 44   1/2/2012 20:00    -5.6             -13.4         54               24
# 45   1/2/2012 21:00    -5.8             -12.8         58               26
# 47   1/2/2012 23:00    -7.4             -14.1         59               17
# 48    1/3/2012 0:00    -9.0             -16.0         57               28
# 50    1/3/2012 2:00   -10.5             -15.8         65               22
# 51    1/3/2012 3:00   -11.3             -18.7         54               33
# 53    1/3/2012 5:00   -12.9             -19.1         60               22
# 54    1/3/2012 6:00   -13.3             -19.3         61               19
# 55    1/3/2012 7:00   -14.0             -19.5         63               19
# 84   1/4/2012 12:00   -13.7             -21.7         51               11
# 86   1/4/2012 14:00   -11.3             -19.0         53                7
# ...

# %%
# str.contains
print("Select The End 50 rows that contains the Weather Condition = 'Snow';")
data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
# Select The End 50 rows that contains the Weather Condition = 'Snow';
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# ...

# %%
print("Q.10)Find all instances when 'Wind Speed is Above 24' And 'Visibility is 25'.")
# Out:
# Q.10)Find all instances when 'Wind Speed is Above 24' And 'Visibility is 25'.

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
print("Select * From data Where Wind Speed_km/h > 24 And Visibility_km = 25")
data[(data['Wind Speed_km/h'] > 24)&(data['Visibility_km'] == 25)]
# Out:
# Select * From data Where Wind Speed_km/h > 24 And Visibility_km = 25
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# ...

# %%
print("Q.11)What is the Mean value of each column against each 'Weather Condition'?")
data.head(2)
# Out:
# Q.11)What is the Mean value of each column against each 'Weather Condition'?
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
#>>Asked ChatGPT for numeric_only = True.
print("Calculate mean() For every Numeric Column Group By Weather Condition.")
data.groupby('Weather Condition').mean(numeric_only=True)
# Out:
# Calculate mean() For every Numeric Column Group By Weather Condition.
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# ...

# %%
print("Q.12) What is the Minimum & Maximum value of each column against each 'Weather Condition'?")
data.head(2)
# Out:
# Q.12) What is the Minimum & Maximum value of each column against each 'Weather Condition'?
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
print("Print Minimum Value for every Category in Weather Condition")
data.groupby('Weather Condition').min(numeric_only=True)
# Out:
# Print Minimum Value for every Category in Weather Condition
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                                     -23.3             -28.5         20
# Cloudy                                    -21.4             -26.8         18
# Drizzle                                     1.1              -0.2         74
# Drizzle,Fog                                 0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                0.9               0.1         92
# Drizzle,Snow,Fog                            0.3              -0.1         92
# Fog                                       -16.0             -17.2         80
# Freezing Drizzle                           -9.0             -12.2         78
# Freezing Drizzle,Fog                       -6.4              -9.0         82
# ...

# %%
print("Print Maximum Number For Every Category in Weather Condition")
data.groupby('Weather Condition').max(numeric_only=True)
# Out:
# Print Maximum Number For Every Category in Weather Condition
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# ...

# %%
print("Q.13)Show all the Records where Weather Condition is Fog.")
# Out:
# Q.13)Show all the Records where Weather Condition is Fog.

# %%
print("Select * From data Where Weather Condition == 'Fog'")
data[data['Weather Condition'] == 'Fog']
# Out:
# Select * From data Where Weather Condition == 'Fog'
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# ...

# %%
print("Q.14)Find all instances when 'Weather is Clear' or 'Visibility is Above 40'.")
data[(data['Weather Condition']=='Clear')&(data['Visibility_km']>40)]
# Out:
# Q.14)Find all instances when 'Weather is Clear' or 'Visibility is Above 40'.
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# 352    1/15/2012 16:00   -15.1             -22.8         52               24
# 425    1/18/2012 17:00   -11.3             -18.8         54               26
# 440     1/19/2012 8:00   -13.7             -18.4         68               19
# 441     1/19/2012 9:00   -12.7             -17.2         69               17
# ...                ...     ...               ...        ...              ...
# 8384   12/15/2012 8:00   -10.7             -15.6         67               13
# 8385   12/15/2012 9:00   -10.4             -15.9         64               19
# 8389  12/15/2012 13:00    -8.4             -14.7         60               19
# 8631  12/25/2012 15:00    -7.1             -13.7         59               17
# ...

# %%
print("Q.15)Find All Instances When:")
# Out:
# Q.15)Find All Instances When:

# %%
print("A.'Weather is Clear'and'Relative Humidity is greater than 50'")
print("or")
print("B.'Visibility is above 40'")
# Out:
# A.'Weather is Clear'and'Relative Humidity is greater than 50'
# or
# B.'Visibility is above 40'

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather Condition]
# Index: []

# %%
#And>>&
#Or>>|
data[(data['Weather Condition']=='Clear')&(data['Rel Hum_%']>50)|(data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data[(data['Weather Condition']=='Clear')&(data['Rel Hum_%']>50)|(data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
print("End of Weather Data Analysis Python Project")
# Out:
# End of Weather Data Analysis Python Project
